# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

games = pd.read_csv('games.csv')
plays = pd.read_csv('plays.csv')
players = pd.read_csv('players.csv')
tackles = pd.read_csv('tackles.csv')
week1 = pd.read_csv('tracking_week_1.csv')

KC_games = games[(games['homeTeamAbbr'] == 'KC') | (games['visitorTeamAbbr'] == 'KC')]
KC_week1 = week1[week1['gameId'] == 2022091110]

# %%
KC_games
# Out:
#          gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 10   2022091110    2022     1  09/11/2022        16:25:00          ARI
# 16   2022091500    2022     2  09/15/2022        20:15:00           KC
# 35   2022092502    2022     3  09/25/2022        13:00:00          IND
# 62   2022100213    2022     4  10/02/2022        20:20:00           TB
# 79   2022101000    2022     5  10/10/2022        20:15:00           KC
# 91   2022101610    2022     6  10/16/2022        16:25:00           KC
# 105  2022102310    2022     7  10/23/2022        16:25:00           SF
# 134  2022110610    2022     9  11/06/2022        20:20:00           KC
#
#     visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 10               KC              21                 44
# 16              LAC              27                 24
# 35               KC              20                 17
# 62               KC              31                 41
# ...

# %%
KC_week1.head()
# Out:
#             gameId  playId    nflId   displayName  frameId  \
# 998223  2022091110      55  40011.0  Travis Kelce        1
# 998224  2022091110      55  40011.0  Travis Kelce        2
# 998225  2022091110      55  40011.0  Travis Kelce        3
# 998226  2022091110      55  40011.0  Travis Kelce        4
# 998227  2022091110      55  40011.0  Travis Kelce        5
#
#                               time  jerseyNumber club playDirection      x  \
# 998223  2022-09-11 16:27:06.400000          87.0   KC          left  87.16
# 998224  2022-09-11 16:27:06.500000          87.0   KC          left  87.15
# 998225  2022-09-11 16:27:06.599999          87.0   KC          left  87.15
# 998226  2022-09-11 16:27:06.700000          87.0   KC          left  87.15
# 998227  2022-09-11 16:27:06.799999          87.0   KC          left  87.15
#
#             y    s    a  dis       o     dir event
# 998223  34.58  0.0  0.0  0.0  228.81  276.41   NaN
# 998224  34.58  0.0  0.0  0.0  228.81  277.02   NaN
# ...

# %%
KC_week1
# Out:
#              gameId  playId    nflId   displayName  frameId  \
# 998223   2022091110      55  40011.0  Travis Kelce        1
# 998224   2022091110      55  40011.0  Travis Kelce        2
# 998225   2022091110      55  40011.0  Travis Kelce        3
# 998226   2022091110      55  40011.0  Travis Kelce        4
# 998227   2022091110      55  40011.0  Travis Kelce        5
# ...             ...     ...      ...           ...      ...
# 1091391  2022091110    4137      NaN      football       17
# 1091392  2022091110    4137      NaN      football       18
# 1091393  2022091110    4137      NaN      football       19
# 1091394  2022091110    4137      NaN      football       20
# 1091395  2022091110    4137      NaN      football       21
#
#                                time  jerseyNumber      club playDirection  \
# 998223   2022-09-11 16:27:06.400000          87.0        KC          left
# 998224   2022-09-11 16:27:06.500000          87.0        KC          left
# ...

# %%
football_week1 = KC_week1[(KC_week1['displayName'] == 'football')]

# %%
football_week1.head()
# Out:
#             gameId  playId  nflId displayName  frameId  \
# 999807  2022091110      55    NaN    football        1
# 999808  2022091110      55    NaN    football        2
# 999809  2022091110      55    NaN    football        3
# 999810  2022091110      55    NaN    football        4
# 999811  2022091110      55    NaN    football        5
#
#                               time  jerseyNumber      club playDirection  \
# 999807  2022-09-11 16:27:06.400000           NaN  football          left
# 999808  2022-09-11 16:27:06.500000           NaN  football          left
# 999809  2022-09-11 16:27:06.599999           NaN  football          left
# 999810  2022-09-11 16:27:06.700000           NaN  football          left
# 999811  2022-09-11 16:27:06.799999           NaN  football          left
#
#                 x      y    s    a  dis   o  dir event
# 999807  85.300003  29.91  0.0  0.0  0.0 NaN  NaN   NaN
# 999808  85.300003  29.91  0.0  0.0  0.0 NaN  NaN   NaN
# ...

# %%
football_week1['dis'].sum()
# Out:
# 2075.509999739006
